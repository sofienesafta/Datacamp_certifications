# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# ### Data Validation

# %% [markdown]
# The dataset contains 15000 rows and 8 columns before cleaning and validation. I have validated all the columns against the criteria in the dataset table:
# * week: numeric values range from 1 to 6 weeks, without missing values.No cleaning is needed.
# * sales_method: categorical values. There are 5 unique values which we transformed to 3 unique values same as the description: 'Email + call' ; 'Call' and 'Email'.There is no missing values.
# * customer_id: caracter values without missing values. There are 15000 unique values as expected.No cleaning is needed.
# * nb_sold: numeric values with no missing data. No cleaning is needed.
# * revenue: numeric continous values with 1047 missing values. We removed dataset rows containing these missing values since they form 7%. The remaining values are rounded to 2 decimal places as expected.
# * years_as_customer : numeric values range from 0 to 63 with no missing values. We should mention that values above 38 years are not logical since the company is founded in 1984. These outlying values(>38) can be caused by typing error.These values should be verified because they are wrong.
# * nb_site_visits: numeric values with no missing values. No cleaning is needed.
# * state: caracter values , 50 unique states with no missing values. No cleaning is needed.
# After cleaning and validation our dataset contains 13926 rows and 8 columns without missing values.

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# ### How many customers were there for each approach

# %% [markdown]
# "Email" approach presents the highest number of customers with almost 7000 ."Call" method comes the second. The observations are not the same across the 3 different sales_methods. We miss the information of whether the number of customer targeted for each tested method is the same . If it is the same we can conclude that the customers are more likely to buy the new products by the way of "Email".

# %% [markdown]
# ![fig1](1.png)

# %% [markdown]
# ### What does the spread of the revenue look like overall? And for each method?

# %% [markdown]
# The majority of the revenue for the new products are below 150 .Nevertheless There are some records  above 150 . To better understand this distribution we have to see the spread of the revenue for each sales method seperately.

# %% [markdown]
# ![fig2](2.png)

# %% [markdown]
# The graph below shows that the three sales methods have different spread of revenue. For the "Call" method the revenue vary from 25 to 75. For the "Email" method the revenue values vary from about 75 to 145. Whereas the revenue for "Email + call" method is above 125. This shows that "Email + call" strategy gives us the highest revenue of the sales.

# %% [markdown]
# ![fig3](3.png)

# %% [markdown]
# ### Was there any difference in revenue over time for each method?

# %% [markdown]
# The highest average revenue over time corresponds to the "Email + call" method as shown in the graph below which confirms what shows the histogram above. This graph shows also that the revenue has increased on average over time for all sales strategies. But this increase is more important for  "Email + call" method . Selling with "Call" strategy  brings the lowest revenue compared to other sales strategies.

# %% [markdown]
# ![fig4](4.png)

# %% [markdown]
# From above we can exclude the "Call" sales method since it is more costfull (takes more time) and provide the less revenue.We can notice also from the bar chart below that the number of customers for "Email" method decreases over time. On the other side this value increases for "Email + call" method. This suggests that the "Email + call" approach is more interesting over time than selling by "Email" strategy.

# %% [markdown]
# ![fig5](5.png)

# %% [markdown]
# ### Is there any difference about the customers in each group

# %% [markdown]
# It is important to check if there is any difference between the customers targeted in each group. We see that the distribution of number of years as custumor within the three groups is done in the same way with a little bit higher values for "Email" and "Call" methods compared to the "Email + call" method, but this difference is not significant. We conclude that there is no significant difference between the customers in each group that may influence on the results of the tested methods.

# %% [markdown]
# ![fig6](6.png)

# %% [markdown]
# ## Business metric

# %% [markdown]
# Since our goal is to increase the amount of new products sold for the next period and therefore the total revenue of sales. I would recommend we use the total revenue of the new products sales last 6 weeks as our metric.
#
# Based on our last 6 weeks data, The estimated total revenue gained from the new products equals to **1 433 685**. The missing values of revenue for each sales method were estimated as the mean of revenue for this method. Therefore, if this number is increasing next 6 weeks, it indicates a very good sign to achieve our goal.

# %% [markdown]
# ## Recommendation

# %% [markdown]
# From all above we can exclude selling products with the "Call" method as it takes more time from the team and it does not bring much income(revenue). We conclude also that  for "Email + call" method the revenue is the highest on average and the number of orders increases over weeks. On the other side the number of orders decreases over time for the "Email" sale strategy. Thus the "Email + call" appoach is more profitable for the company.
#
# For the following weeks, I would recommend we can focus on the following steps:
#
# - Using the defined key metric to monitor whether the total revenue of new products is increasing.
# - Using the strategy of **"Email + call"** for selling the new products because it is more profitable than the other strategies (more global revenue and does not require much time from the team).
# - Collecting new data related to the new products types or categories to further analysis and to identify the best sales strategy that works for each type of new products.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation
